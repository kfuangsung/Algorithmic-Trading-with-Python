# %%
import numpy as np 
import pandas as pd 
import requests
from tqdm.notebook import tqdm_notebook
tqdm_notebook.pandas()
from datetime import datetime
# Out:
# C:\Users\kfuan\Anaconda3\envs\dl_fastai\lib\site-packages\tqdm\std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
stocks_list = pd.read_csv('../data/sp_500_stocks.csv')

# %%
stocks_list
# Out:
#     Ticker
# 0        A
# 1      AAL
# 2      AAP
# 3     AAPL
# 4     ABBV
# ..     ...
# 500    YUM
# 501    ZBH
# 502   ZBRA
# 503   ZION
# 504    ZTS
#
# [505 rows x 1 columns]

# %%
base_url = "https://sandbox.iexapis.com/stable/"

# %%
from secrets import IEX_CLOUD_API_TOKEN

# %%
def chunks(input_list, n):
    for i in range(0, len(input_list), n):
        yield input_list[i : i+n]

# %%
batch_symbols = [name for name in chunks(stocks_list.Ticker.values, 100)]

# %%
print(batch_symbols[0])
# Out:
# ['A' 'AAL' 'AAP' 'AAPL' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ACN' 'ADBE' 'ADI' 'ADM'
#  'ADP' 'ADSK' 'AEE' 'AEP' 'AES' 'AFL' 'AIG' 'AIV' 'AIZ' 'AJG' 'AKAM' 'ALB'
#  'ALGN' 'ALK' 'ALL' 'ALLE' 'ALXN' 'AMAT' 'AMCR' 'AMD' 'AME' 'AMGN' 'AMP'
#  'AMT' 'AMZN' 'ANET' 'ANSS' 'ANTM' 'AON' 'AOS' 'APA' 'APD' 'APH' 'APTV'
#  'ARE' 'ATO' 'ATVI' 'AVB' 'AVGO' 'AVY' 'AWK' 'AXP' 'AZO' 'BA' 'BAC' 'BAX'
#  'BBY' 'BDX' 'BEN' 'BF.B' 'BIIB' 'BIO' 'BK' 'BKNG' 'BKR' 'BLK' 'BLL' 'BMY'
#  'BR' 'BRK.B' 'BSX' 'BWA' 'BXP' 'C' 'CAG' 'CAH' 'CARR' 'CAT' 'CB' 'CBOE'
#  'CBRE' 'CCI' 'CCL' 'CDNS' 'CDW' 'CE' 'CERN' 'CF' 'CFG' 'CHD' 'CHRW'
#  'CHTR' 'CI' 'CINF' 'CL' 'CLX' 'CMA' 'CMCSA']

# %%
batch_strings = []
for batch in batch_symbols:
    batch_strings.append(",".join(batch))

# %%
print(batch_strings[0])
# Out:
# A,AAL,AAP,AAPL,ABBV,ABC,ABMD,ABT,ACN,ADBE,ADI,ADM,ADP,ADSK,AEE,AEP,AES,AFL,AIG,AIV,AIZ,AJG,AKAM,ALB,ALGN,ALK,ALL,ALLE,ALXN,AMAT,AMCR,AMD,AME,AMGN,AMP,AMT,AMZN,ANET,ANSS,ANTM,AON,AOS,APA,APD,APH,APTV,ARE,ATO,ATVI,AVB,AVGO,AVY,AWK,AXP,AZO,BA,BAC,BAX,BBY,BDX,BEN,BF.B,BIIB,BIO,BK,BKNG,BKR,BLK,BLL,BMY,BR,BRK.B,BSX,BWA,BXP,C,CAG,CAH,CARR,CAT,CB,CBOE,CBRE,CCI,CCL,CDNS,CDW,CE,CERN,CF,CFG,CHD,CHRW,CHTR,CI,CINF,CL,CLX,CMA,CMCSA

# %% [markdown]
# # Simple P/E based

# %%
quant_value_portfolio = stocks_list.copy()

# %%
col_names = ['latestPrice', 'peRatio']

# %%
quant_value_portfolio[col_names] = None

# %%
quant_value_portfolio
# Out:
#     Ticker latestPrice peRatio
# 0        A        None    None
# 1      AAL        None    None
# 2      AAP        None    None
# 3     AAPL        None    None
# 4     ABBV        None    None
# ..     ...         ...     ...
# 500    YUM        None    None
# 501    ZBH        None    None
# 502   ZBRA        None    None
# 503   ZION        None    None
# 504    ZTS        None    None
#
# [505 rows x 3 columns]

# %%
def batch_api_call(symbols):
    batch_url = base_url+f"stock/market/batch?symbols={symbols}&types=quote&filter=latestPrice,peRatio&token={IEX_CLOUD_API_TOKEN}"
    return requests.get(batch_url).json()

# %%
data = batch_api_call(batch_strings[-1])

# %%
data
# Out:
# {'YUM': {'quote': {'latestPrice': 103.66, 'peRatio': 31.39}},
#  'ZBH': {'quote': {'latestPrice': 164.73, 'peRatio': -227.26}},
#  'ZBRA': {'quote': {'latestPrice': 424.54, 'peRatio': 47.99}},
#  'ZION': {'quote': {'latestPrice': 49.93, 'peRatio': 21.26}},
#  'ZTS': {'quote': {'latestPrice': 162.76, 'peRatio': 46.84}}}

# %%
d0 = datetime.now()

start = 0
for batch in tqdm_notebook(batch_strings):
    data = batch_api_call(batch)
    # use pandas.apply to each row in each batch
    for col in col_names:
        quant_value_portfolio[col][start:start+len(data)] = quant_value_portfolio['Ticker'][start:start+len(data)].apply(lambda x: data[x]['quote'][col])
    
    start += len(data)
    
print(datetime.now() - d0)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=6.0), HTML(value='')))
# 0:00:06.224152

# %%
quant_value_portfolio
# Out:
#     Ticker latestPrice peRatio
# 0        A      125.13   55.12
# 1      AAL        18.1   -1.27
# 2      AAP      164.37   23.71
# 3     AAPL     138.936   38.68
# 4     ABBV      109.66    23.9
# ..     ...         ...     ...
# 500    YUM      107.39   31.32
# 501    ZBH         162  -219.6
# 502   ZBRA      422.02   48.19
# 503   ZION       49.85   20.97
# 504    ZTS      159.18   46.69
#
# [505 rows x 3 columns]

# %%
pe_is_positive = quant_value_portfolio['peRatio'] > 0
quant_value_portfolio = quant_value_portfolio[pe_is_positive]
quant_value_portfolio.sort_values(by='peRatio', inplace=True)
quant_value_portfolio.reset_index(drop=True, inplace=True)
quant_value_portfolio = quant_value_portfolio[:50]
display(quant_value_portfolio.head(10))
print(quant_value_portfolio.shape)
# Out:
# <ipython-input-20-16bb2c5d053d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quant_value_portfolio.sort_values(by='peRatio', inplace=True)
#   Ticker latestPrice peRatio
# 0    NRG       44.03    2.63
# 1   NLOK       21.63    4.22
# 2    AIV        4.84    4.79
# 3    UNM       24.72    5.31
# 4    BIO      616.58     5.4
# 5    AFL       47.42     7.3
# 6    ALL      108.51     7.7
# 7    CPB       49.15    8.21
# 8    KIM          17    8.62
# 9   EBAY       61.34    8.68
# (50, 3)

# %%
def get_equal_position_size(n):
    global portfolio_size
    global position_size
    while True:
        try:
            portfolio_size = float(input('Enter the size of portfolio: '))
            break
        except:
            print('Invalid Input!')
            continue
    position_size = portfolio_size/n
    print(f'Porfolio size: {portfolio_size}\nPosition size: {position_size}')

# %%
get_equal_position_size(quant_value_portfolio.shape[0])
# Out:
# Enter the size of portfolio: dasld
# Invalid Input!
# Enter the size of portfolio: ogfd
# Invalid Input!
# Enter the size of portfolio: 4582$
# Invalid Input!
# Enter the size of portfolio: 7582502
# Porfolio size: 7582502.0
# Position size: 151650.04

# %%
print(f'port. size: {portfolio_size}\npos. size: {position_size}')
# Out:
# port. size: 7582502.0
# pos. size: 151650.04

# %%
quant_value_portfolio['amount of shares to buy'] = np.floor(position_size/quant_value_portfolio['latestPrice'])

# %%
quant_value_portfolio.head(10)
# Out:
#   Ticker latestPrice peRatio amount of shares to buy
# 0    NRG       44.03    2.63                    3444
# 1   NLOK       21.63    4.22                    7011
# 2    AIV        4.84    4.79                   31332
# 3    UNM       24.72    5.31                    6134
# 4    BIO      616.58     5.4                     245
# 5    AFL       47.42     7.3                    3198
# 6    ALL      108.51     7.7                    1397
# 7    CPB       49.15    8.21                    3085
# 8    KIM          17    8.62                    8920
# 9   EBAY       61.34    8.68                    2472

# %% [markdown]
# # More multiples based
# <ol>
#     <li>P/E</li>
#     <li>P/B</li>
#     <li>P/S</li>
#     <li>EV/EBITDA</li>
#     <li>EV/GP (gross profit)</li>
# </ol>

# %%
multiples_ratio_portfolio = stocks_list.copy()

# %%
multiples_ratio_portfolio
# Out:
#     Ticker
# 0        A
# 1      AAL
# 2      AAP
# 3     AAPL
# 4     ABBV
# ..     ...
# 500    YUM
# 501    ZBH
# 502   ZBRA
# 503   ZION
# 504    ZTS
#
# [505 rows x 1 columns]

# %%
col_quote = ['latestPrice', 'peRatio']
col_advanced_stats = ['priceToBook', 'priceToSales', 'enterpriseValue', 'EBITDA', 'grossProfit']

# %%
multiples_ratio_portfolio[col_quote] = None 
multiples_ratio_portfolio[col_advanced_stats] = None

# %%
multiples_ratio_portfolio.head()
# Out:
#   Ticker latestPrice peRatio priceToBook priceToSales enterpriseValue EBITDA  \
# 0      A        None    None        None         None            None   None
# 1    AAL        None    None        None         None            None   None
# 2    AAP        None    None        None         None            None   None
# 3   AAPL        None    None        None         None            None   None
# 4   ABBV        None    None        None         None            None   None
#
#   grossProfit
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None

# %%
def batch_api_ratio(symbols):
    batch_url = (base_url+f"stock/market/batch?symbols={symbols}&types=quote,advanced-stats&token={IEX_CLOUD_API_TOKEN}")
    return requests.get(batch_url).json()

# %%
batch_api_ratio(batch_strings[-1])
# Out:
# {'YUM': {'advanced-stats': {'beta': 0.9520982779588391,
#    'totalCash': 1111209485,
#    'currentDebt': 1567053669,
#    'revenue': 5858416657,
#    'grossProfit': 4369491443,
#    'totalRevenue': 5718581968,
#    'EBITDA': 1812123103,
#    'revenuePerShare': 19.05,
#    'revenuePerEmployee': 169476.03,
#    'debtToEquity': -0.7767476291191573,
#    'profitMargin': 0.1985818587920967,
#    'enterpriseValue': 42048469312,
#    'enterpriseValueToRevenue': 7.43,
#    'priceToSales': 5.81,
#    'priceToBook': -4.08,
#    'forwardPERatio': 26.32079214430469,
#    'pegRatio': -6.455975758659115,
#    'peHigh': 11.52395031585058,
#    'peLow': 6.286845829355523,
#    'week52highDate': '2020-12-19',
#    'week52lowDate': '2020-03-11',
#    'putCallRatio': 0.8343151406412874,
#    'companyName': 'Yum Brands Inc.',
#    'marketcap': 31981578491,
#    'week52high': 113.04,
#    'week52low': 56.8,
#    'week52change': 0.012095626020614427,
#    'sharesOutstanding': 309062547,
#    'float': None,
#    'avg10Volume': 2052381,
#    'avg30Volume': 1684166,
#    'day200MovingAvg': 101.81,
#    'day50MovingAvg': 106.96,
#    'employees': None,
#    'ttmEPS': 3.56,
#    'ttmDividendRate': 1.8721759764046757,
#    'dividendYield': 0.01832511738373089,
#    'nextDividendDate': '2021-01-28',
#    'exDividendDate': '2020-11-18',
#    'nextEarningsDate': '2021-02-02',
#    'peRatio': 30.40755427978268,
#    'maxChangePercent': 12.950796031068124,
#    'year5ChangePercent': 1.1921602602804533,
#    'year2ChangePercent': 0.12973641420272242,
#    'year1ChangePercent': -0.01674901194234678,
#    'ytdChangePercent': -0.0518118376510085,
#    'month6ChangePercent': 0.13384443811246377,
#    'month3ChangePercent': 0.051127523728356994,
#    'month1ChangePercent': -0.026744706899966098,
#    'day30ChangePercent': -0.02815166660193699,
#    'day5ChangePercent': 0.004611024743941269},
#   'quote': {'symbol': 'YUM',
#    'companyName': 'Yum Brands Inc.',
#    'primaryExchange': 'NSO XCEWE YTCN CKHONE GAI.RK,',
#    'calculationPrice': 'close',
#    'open': None,
#    'openTime': None,
#    'openSource': 'ifcoaifl',
#    'close': None,
#    'closeTime': None,
#    'closeSource': 'aiofilcf',
#    'high': None,
#    'highTime': 1656888199902,
#    'highSource': 'rlte eucpyd eeni5m d1ia',
#    'low': None,
#    'lowTime': 1635960310714,
#    'lowSource': ' rciylipd aent51edmuee ',
#    'latestPrice': 105.66,
#    'latestSource': 'Close',
#    'latestTime': 'February 4, 2021',
#    'latestUpdate': 1680673950663,
#    'latestVolume': None,
#    'iexRealtimePrice': None,
#    'iexRealtimeSize': None,
#    'iexLastUpdated': None,
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'extendedPrice': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPriceTime': None,
#    'previousClose': 109.9,
#    'previousVolume': 1608317,
#    'change': -1.76,
#    'changePercent': -0.01705,
#    'volume': None,
#    'iexMarketPercent': None,
#    'iexVolume': None,
#    'avgTotalVolume': 1714729,
#    'iexBidPrice': None,
#    'iexBidSize': None,
#    'iexAskPrice': None,
#    'iexAskSize': None,
#    'iexOpen': 104.028,
#    'iexOpenTime': 1682593397435,
#    'iexClose': 107.173,
#    'iexCloseTime': 1665638720134,
#    'marketCap': 32143620802,
#    'peRatio': 30.31,
#    'week52High': 115.15,
#    'week52Low': 58.2,
#    'ytdChange': -0.0712945215198791,
#    'lastTradeTime': 1654580715472,
#    'isUSMarketOpen': False}},
#  'ZBH': {'advanced-stats': {'beta': 1.0264857833042842,
#    'totalCash': 980935309,
#    'currentDebt': 2353612167,
#    'revenue': 7176637843,
#    'grossProfit': 5028279341,
#    'totalRevenue': 7135208914,
#    'EBITDA': 1510160586,
#    'revenuePerShare': 34.54,
#    'revenuePerEmployee': 399604.52,
#    'debtToEquity': 2.105702556425419,
#    'profitMargin': -0.022153420038507753,
#    'enterpriseValue': 41606100726,
#    'enterpriseValueToRevenue': 5.85,
#    'priceToSales': 4.89,
#    'priceToBook': 2.93,
#    'forwardPERatio': 20.674061193210914,
#    'pegRatio': 3.4241478975082886,
#    'peHigh': 21.216660698043,
#    'peLow': 15.099265678347917,
#    'week52highDate': '2021-01-16',
#    'week52lowDate': '2020-03-07',
#    'putCallRatio': 0.8492527541811212,
#    'companyName': 'Zimmer Biomet Holdings Inc',
#    'marketcap': 34747456553,
#    'week52high': 166.68,
#    'week52low': 81.54,
#    'week52change': 0.019117643035865717,
#    'sharesOutstanding': 208668331,
#    'float': None,
#    'avg10Volume': 1579221,
#    'avg30Volume': 1383537,
#    'day200MovingAvg': 147.52,
#    'day50MovingAvg': 156.7,
#    'employees': None,
#    'ttmEPS': -0.7526,
#    'ttmDividendRate': 0.9831749568279277,
#    'dividendYield': 0.006118506159149307,
#    'nextDividendDate': None,
#    'exDividendDate': '2020-12-22',
#    'nextEarningsDate': '2021-01-29',
#    'peRatio': -228.4693497186515,
#    'maxChangePercent': 1.16957499022617,
#    'year5ChangePercent': 0.7195110037933599,
#    'year2ChangePercent': 0.3908802956608598,
#    'year1ChangePercent': 0.03398943109891446,
#    'ytdChangePercent': 0.04311393078710506,
#    'month6ChangePercent': 0.23923661162288587,
#    'month3ChangePercent': 0.18434802174105955,
#    'month1ChangePercent': 0.05124532862810122,
#    'day30ChangePercent': 0.03185253806412541,
#    'day5ChangePercent': 0.023950373301228},
#   'quote': {'symbol': 'ZBH',
#    'companyName': 'Zimmer Biomet Holdings Inc',
#    'primaryExchange': 'SRNNHEN OCCCTIOGW.X EY KE, AK',
#    'calculationPrice': 'close',
#    'open': None,
#    'openTime': None,
#    'openSource': 'afiofcil',
#    'close': None,
#    'closeTime': None,
#    'closeSource': 'aiicoflf',
#    'high': None,
#    'highTime': 1627069340468,
#    'highSource': 'eep  1udymtielrci5aend ',
#    'low': None,
#    'lowTime': 1643683417957,
#    'lowSource': '1e  pr eemy5ldeuitidnca',
#    'latestPrice': 161.2,
#    'latestSource': 'Close',
#    'latestTime': 'February 4, 2021',
#    'latestUpdate': 1665593723270,
#    'latestVolume': None,
#    'iexRealtimePrice': None,
#    'iexRealtimeSize': None,
#    'iexLastUpdated': None,
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'extendedPrice': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPriceTime': None,
#    'previousClose': 159.07,
#    'previousVolume': 943083,
#    'change': 2.25,
#    'changePercent': 0.01373,
#    'volume': None,
#    'iexMarketPercent': None,
#    'iexVolume': None,
#    'avgTotalVolume': 1343851,
#    'iexBidPrice': None,
#    'iexBidSize': None,
#    'iexAskPrice': None,
#    'iexAskSize': None,
#    'iexOpen': 165.05,
#    'iexOpenTime': 1665925477662,
#    'iexClose': 164.24,
#    'iexCloseTime': 1646896612888,
#    'marketCap': 34622302334,
#    'peRatio': -222.51,
#    'week52High': 167.35,
#    'week52Low': 80.84,
#    'ytdChange': 0.05702162532250311,
#    'lastTradeTime': 1640522848432,
#    'isUSMarketOpen': False}},
#  'ZBRA': {'advanced-stats': {'beta': 1.1848704616659873,
#    'totalCash': 39968564,
#    'currentDebt': 1765538322,
#    'revenue': 4511560823,
#    'grossProfit': 1982567082,
#    'totalRevenue': 4403242655,
#    'EBITDA': 726134094,
#    'revenuePerShare': 85.2,
#    'revenuePerEmployee': 607412.16,
#    'debtToEquity': 2.822407032227585,
#    'profitMargin': 0.11283189635266225,
#    'enterpriseValue': 24317065252,
#    'enterpriseValueToRevenue': 5.48,
#    'priceToSales': 5.16,
#    'priceToBook': 11.69,
#    'forwardPERatio': 28.768312208553667,
#    'pegRatio': -20.1909482673997,
#    'peHigh': 33.8698636568413,
#    'peLow': 19.25526131850047,
#    'week52highDate': '2020-12-28',
#    'week52lowDate': '2020-03-05',
#    'putCallRatio': 1.028467790657485,
#    'companyName': 'Zebra Technologies Corp.',
#    'marketcap': 22390206453,
#    'week52high': 421.38,
#    'week52low': 163.86,
#    'week52change': 0.6399073792039586,
#    'sharesOutstanding': 55833420,
#    'float': None,
#    'avg10Volume': 248967,
#    'avg30Volume': 263710,
#    'day200MovingAvg': 335.44,
#    'day50MovingAvg': 412.11,
#    'employees': None,
#    'ttmEPS': 9.18,
#    'ttmDividendRate': None,
#    'dividendYield': None,
#    'nextDividendDate': None,
#    'exDividendDate': None,
#    'nextEarningsDate': None,
#    'peRatio': 46.89052599461824,
#    'maxChangePercent': 11.01697821323127,
#    'year5ChangePercent': 5.770137838255057,
#    'year2ChangePercent': 1.341774024883193,
#    'year1ChangePercent': 0.668572259359334,
#    'ytdChangePercent': 0.05991148304519683,
#    'month6ChangePercent': 0.44276084353533,
#    'month3ChangePercent': 0.2404104354502435,
#    'month1ChangePercent': 0.08010205172943434,
#    'day30ChangePercent': 0.0726052143149145,
#    'day5ChangePercent': 0.037593989847318814},
#   'quote': {'symbol': 'ZBRA',
#    'companyName': 'Zebra Technologies Corp. - Class A',
#    'primaryExchange': 'A/G)LB KESNQOENTLRELCASTSM (AAD G',
#    'calculationPrice': 'close',
#    'open': None,
#    'openTime': None,
#    'openSource': 'falicfoi',
#    'close': None,
#    'closeTime': None,
#    'closeSource': 'iofcfail',
#    'high': None,
#    'highTime': 1618240317697,
#    'highSource': 'retmre cI  lEeiipXa',
#    'low': None,
#    'lowTime': 1692525005246,
#    'lowSource': 'aem  IiplXreerE itc',
#    'latestPrice': 421.79,
#    'latestSource': 'Close',
#    'latestTime': 'February 4, 2021',
#    'latestUpdate': 1630669075424,
#    'latestVolume': None,
#    'iexRealtimePrice': None,
#    'iexRealtimeSize': None,
#    'iexLastUpdated': None,
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'extendedPrice': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPriceTime': None,
#    'previousClose': 411.64,
#    'previousVolume': 209476,
#    'change': 3.8,
#    'changePercent': 0.00931,
#    'volume': None,
#    'iexMarketPercent': None,
#    'iexVolume': None,
#    'avgTotalVolume': 273647,
#    'iexBidPrice': None,
#    'iexBidSize': None,
#    'iexAskPrice': None,
#    'iexAskSize': None,
#    'iexOpen': 418.22,
#    'iexOpenTime': 1679072570060,
#    'iexClose': 407.49,
#    'iexCloseTime': 1615064777887,
#    'marketCap': 22020845731,
#    'peRatio': 47.99,
#    'week52High': 427.54,
#    'week52Low': 164.96,
#    'ytdChange': 0.07118323856649621,
#    'lastTradeTime': 1626937379836,
#    'isUSMarketOpen': False}},
#  'ZION': {'advanced-stats': {'beta': 1.0926474485161601,
#    'totalCash': None,
#    'currentDebt': 71467909018,
#    'revenue': 3124064075,
#    'grossProfit': 2568006735,
#    'totalRevenue': 3122815051,
#    'EBITDA': 695413216,
#    'revenuePerShare': 19.22,
#    'revenuePerEmployee': 308863.44,
#    'debtToEquity': 10.60735449404533,
#    'profitMargin': 0.132607592416621,
#    'enterpriseValue': 8078738453,
#    'enterpriseValueToRevenue': 2.62,
#    'priceToSales': 2.67,
#    'priceToBook': 1.13,
#    'forwardPERatio': 11.813154945587604,
#    'pegRatio': -0.4417137466247904,
#    'peHigh': 22.09836847921487,
#    'peLow': 10.3746553947621,
#    'week52highDate': '2020-12-31',
#    'week52lowDate': '2020-03-20',
#    'putCallRatio': None,
#    'companyName': 'Zions Bancorporation N.A',
#    'marketcap': 7938065914,
#    'week52high': 53.32,
#    'week52low': 23.76,
#    'week52change': 0.06483520243454792,
#    'sharesOutstanding': 165853950,
#    'float': None,
#    'avg10Volume': 1662307,
#    'avg30Volume': 1572057,
#    'day200MovingAvg': 38.13,
#    'day50MovingAvg': 46.19,
#    'employees': None,
#    'ttmEPS': 2.42,
#    'ttmDividendRate': 1.386974069715455,
#    'dividendYield': 0.028914744234923944,
#    'nextDividendDate': None,
#    'exDividendDate': '2020-11-08',
#    'nextEarningsDate': None,
#    'peRatio': 19.87474707939,
#    'maxChangePercent': -0.006505283370189087,
#    'year5ChangePercent': -0.006576812549468913,
#    'year2ChangePercent': 0.04959692824563172,
#    'year1ChangePercent': 0.07554496997533608,
#    'ytdChangePercent': 0.11131055860942783,
#    'month6ChangePercent': 0.547426710142559,
#    'month3ChangePercent': 0.5776468999513431,
#    'month1ChangePercent': 0.12713375579074865,
#    'day30ChangePercent': 0.10587358161835353,
#    'day5ChangePercent': 0.06997555180110285},
#   'quote': {'symbol': 'ZION',
#    'companyName': 'Zions Bancorporation N.A',
#    'primaryExchange': '/TOA ( NLAETSQSMK LEBSGNADLGE)ARC',
#    'calculationPrice': 'close',
#    'open': None,
#    'openTime': None,
#    'openSource': 'acofifli',
#    'close': None,
#    'closeTime': None,
#    'closeSource': 'ciaffoli',
#    'high': None,
#    'highTime': None,
#    'highSource': None,
#    'low': None,
#    'lowTime': None,
#    'lowSource': None,
#    'latestPrice': 48.51,
#    'latestSource': 'Close',
#    'latestTime': 'February 4, 2021',
#    'latestUpdate': 1624345933144,
#    'latestVolume': None,
#    'iexRealtimePrice': None,
#    'iexRealtimeSize': None,
#    'iexLastUpdated': None,
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'extendedPrice': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPriceTime': None,
#    'previousClose': 48.3,
#    'previousVolume': 1852344,
#    'change': 2.29,
#    'changePercent': 0.04898,
#    'volume': None,
#    'iexMarketPercent': None,
#    'iexVolume': None,
#    'avgTotalVolume': 1570338,
#    'iexBidPrice': None,
#    'iexBidSize': None,
#    'iexAskPrice': None,
#    'iexAskSize': None,
#    'iexOpen': 48.56,
#    'iexOpenTime': 1614879029664,
#    'iexClose': 50.16,
#    'iexCloseTime': 1653131869466,
#    'marketCap': 8300719363,
#    'peRatio': 20.85,
#    'week52High': 52.45,
#    'week52Low': 24.35,
#    'ytdChange': 0.15789921372586876,
#    'lastTradeTime': 1689415176113,
#    'isUSMarketOpen': False}},
#  'ZTS': {'advanced-stats': {'beta': 0.9770455408600878,
#    'totalCash': 3723160749,
#    'currentDebt': 2440631139,
#    'revenue': 6746820555,
#    'grossProfit': 4772828266,
#    'totalRevenue': 6715905188,
#    'EBITDA': 2544828077,
#    'revenuePerShare': 13.87,
#    'revenuePerEmployee': 742653.17,
#    'debtToEquity': 3.8190250353891866,
#    'profitMargin': 0.2593491249075414,
#    'enterpriseValue': 81298390473,
#    'enterpriseValueToRevenue': 12.51,
#    'priceToSales': 11.54,
#    'priceToBook': 20.87,
#    'forwardPERatio': None,
#    'pegRatio': 3.050133951074461,
#    'peHigh': 37.61509910740392,
#    'peLow': 23.83582333317648,
#    'week52highDate': '2020-10-26',
#    'week52lowDate': '2020-03-18',
#    'putCallRatio': 0.8050583884276072,
#    'companyName': 'Zoetis Inc',
#    'marketcap': 77107670624,
#    'week52high': 175.86,
#    'week52low': 96.8,
#    'week52change': 0.1386095411323524,
#    'sharesOutstanding': 495170226,
#    'float': None,
#    'avg10Volume': 1911661,
#    'avg30Volume': 1859269,
#    'day200MovingAvg': 165.25,
#    'day50MovingAvg': 163.87,
#    'employees': None,
#    'ttmEPS': 3.52,
#    'ttmDividendRate': 0.883771530073922,
#    'dividendYield': 0.005661995671250457,
#    'nextDividendDate': None,
#    'exDividendDate': '2021-01-06',
#    'nextEarningsDate': None,
#    'peRatio': 46.53164027136121,
#    'maxChangePercent': 4.481393358017785,
#    'year5ChangePercent': 3.031016712627863,
#    'year2ChangePercent': 0.8361679447246514,
#    'year1ChangePercent': 0.1361207366885773,
#    'ytdChangePercent': -0.05267322298080897,
#    'month6ChangePercent': 0.011366933890137662,
#    'month3ChangePercent': -0.10192929271453054,
#    'month1ChangePercent': -0.03963542556366165,
#    'day30ChangePercent': -0.04722657989641335,
#    'day5ChangePercent': 0.003836004079092023},
#   'quote': {'symbol': 'ZTS',
#    'companyName': 'Zoetis Inc - Class A',
#    'primaryExchange': 'GONE KH.NA XNKEC, ITWSOCEYRC ',
#    'calculationPrice': 'close',
#    'open': None,
#    'openTime': None,
#    'openSource': 'aolfcfii',
#    'close': None,
#    'closeTime': None,
#    'closeSource': 'ficlfoai',
#    'high': None,
#    'highTime': 1661982991013,
#    'highSource': 'ee51edtnypciea rmi u ld',
#    'low': None,
#    'lowTime': 1636472510250,
#    'lowSource': 'ciedemd aue rtl eiy5p1n',
#    'latestPrice': 163.25,
#    'latestSource': 'Close',
#    'latestTime': 'February 4, 2021',
#    'latestUpdate': 1625909503813,
#    'latestVolume': None,
#    'iexRealtimePrice': None,
#    'iexRealtimeSize': None,
#    'iexLastUpdated': None,
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'extendedPrice': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPriceTime': None,
#    'previousClose': 161.11,
#    'previousVolume': 1734424,
#    'change': 1.9,
#    'changePercent': 0.01273,
#    'volume': None,
#    'iexMarketPercent': None,
#    'iexVolume': None,
#    'avgTotalVolume': 1885643,
#    'iexBidPrice': None,
#    'iexBidSize': None,
#    'iexAskPrice': None,
#    'iexAskSize': None,
#    'iexOpen': 158.73,
#    'iexOpenTime': 1677816266293,
#    'iexClose': 162.97,
#    'iexCloseTime': 1638178752731,
#    'marketCap': 76392883211,
#    'peRatio': 46.54,
#    'week52High': 176.89,
#    'week52Low': 93.26,
#    'ytdChange': -0.03987385702516845,
#    'lastTradeTime': 1630441836527,
#    'isUSMarketOpen': False}}}

# %%
d0 = datetime.now()

start = 0
for batch in tqdm_notebook(batch_strings):
    data = batch_api_ratio(batch)
    
    for col in col_quote:
        multiples_ratio_portfolio[col][start:start+len(data)] =  \
        multiples_ratio_portfolio['Ticker'][start:start+len(data)].apply(lambda x: data[x]['quote'][col])
    
    for col in col_advanced_stats:
        multiples_ratio_portfolio[col][start:start+len(data)] =  \
        multiples_ratio_portfolio['Ticker'][start:start+len(data)].apply(lambda x: data[x]['advanced-stats'][col])
    
    start += len(data)

    print(f'Timed{datetime.now() - d0}')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=6.0), HTML(value='')))
# Timed0:00:01.738767
# Timed0:00:03.352250
# Timed0:00:04.923391
# Timed0:00:06.522961
# Timed0:00:08.184899
# Timed0:00:09.207928

# %%
multiples_ratio_portfolio
# Out:
#     Ticker latestPrice peRatio priceToBook priceToSales enterpriseValue  \
# 0        A      127.02   54.53        8.06         7.21     4.07756e+10
# 1      AAL        17.8   -1.27          -2        0.448     3.66355e+10
# 2      AAP      162.69   24.05        2.89         1.13     1.12223e+10
# 3     AAPL     137.749   38.06        35.6          8.2     2.36557e+12
# 4     ABBV      108.64    24.5       12.85         4.85     2.76515e+11
# ..     ...         ...     ...         ...          ...             ...
# 500    YUM      103.08   31.04       -4.09         5.69     41391308399
# 501    ZBH      163.62 -219.34         2.9         4.92     42139512153
# 502   ZBRA      410.07   48.01       11.53         5.15     23299202223
# 503   ZION       48.77   21.43        1.12         2.71      8060676041
# 504    ZTS      159.51   47.18       20.81        11.45     82558439051
#
#           EBITDA  grossProfit
# 0    1.20207e+09  2.96906e+09
# 1   -5.72463e+09  2.50112e+10
# 2    1.01436e+09  4.52498e+09
# 3    8.57775e+10  1.18216e+11
# 4    1.68523e+10   2.8728e+10
# ..           ...          ...
# 500   1881405256   4240832750
# 501   1477042947   5077159469
# 502    739186463   1961901169
# 503    695074702   2634022708
# 504   2514040032   4638930652
#
# [505 rows x 8 columns]

# %%
multiples_ratio_portfolio['EV/EBITDA'] = multiples_ratio_portfolio.enterpriseValue / multiples_ratio_portfolio.EBITDA
multiples_ratio_portfolio['EV/GrossProfit'] = multiples_ratio_portfolio.enterpriseValue / multiples_ratio_portfolio.grossProfit

# %%
multiples_ratio_portfolio
# Out:
#     Ticker latestPrice peRatio priceToBook priceToSales enterpriseValue  \
# 0        A      127.02   54.53        8.06         7.21     4.07756e+10
# 1      AAL        17.8   -1.27          -2        0.448     3.66355e+10
# 2      AAP      162.69   24.05        2.89         1.13     1.12223e+10
# 3     AAPL     137.749   38.06        35.6          8.2     2.36557e+12
# 4     ABBV      108.64    24.5       12.85         4.85     2.76515e+11
# ..     ...         ...     ...         ...          ...             ...
# 500    YUM      103.08   31.04       -4.09         5.69     41391308399
# 501    ZBH      163.62 -219.34         2.9         4.92     42139512153
# 502   ZBRA      410.07   48.01       11.53         5.15     23299202223
# 503   ZION       48.77   21.43        1.12         2.71      8060676041
# 504    ZTS      159.51   47.18       20.81        11.45     82558439051
#
#           EBITDA  grossProfit EV/EBITDA EV/GrossProfit
# 0    1.20207e+09  2.96906e+09   33.9211        13.7335
# 1   -5.72463e+09  2.50112e+10  -6.39962        1.46476
# 2    1.01436e+09  4.52498e+09   11.0634        2.48007
# 3    8.57775e+10  1.18216e+11    27.578        20.0106
# 4    1.68523e+10   2.8728e+10   16.4082         9.6253
# ..           ...          ...       ...            ...
# 500   1881405256   4240832750   22.0002        9.76018
# 501   1477042947   5077159469   28.5296        8.29982
# 502    739186463   1961901169   31.5201        11.8758
# 503    695074702   2634022708   11.5968        3.06022
# 504   2514040032   4638930652    32.839        17.7969
#
# [505 rows x 10 columns]

# %%
multiples_ratio_portfolio.drop(columns=['enterpriseValue', 'EBITDA', 'grossProfit'], inplace=True)

# %%
multiples_ratio_portfolio.columns.values[2:]
# Out:
# array(['peRatio', 'priceToBook', 'priceToSales', 'EV/EBITDA',
#        'EV/GrossProfit'], dtype=object)

# %%
for col in multiples_ratio_portfolio.columns.values[2:]:
    multiples_ratio_portfolio[col+" Percentiles"] = multiples_ratio_portfolio[col].rank(pct=True)

# %%
multiples_ratio_portfolio
# Out:
#     Ticker latestPrice peRatio priceToBook priceToSales EV/EBITDA  \
# 0        A      127.02   54.53        8.06         7.21   33.9211
# 1      AAL        17.8   -1.27          -2        0.448  -6.39962
# 2      AAP      162.69   24.05        2.89         1.13   11.0634
# 3     AAPL     137.749   38.06        35.6          8.2    27.578
# 4     ABBV      108.64    24.5       12.85         4.85   16.4082
# ..     ...         ...     ...         ...          ...       ...
# 500    YUM      103.08   31.04       -4.09         5.69   22.0002
# 501    ZBH      163.62 -219.34         2.9         4.92   28.5296
# 502   ZBRA      410.07   48.01       11.53         5.15   31.5201
# 503   ZION       48.77   21.43        1.12         2.71   11.5968
# 504    ZTS      159.51   47.18       20.81        11.45    32.839
#
#     EV/GrossProfit  peRatio Percentiles  priceToBook Percentiles  \
# 0          13.7335             0.861789                 0.772541
# 1          1.46476             0.157520                 0.051230
# 2          2.48007             0.469512                 0.409836
# 3          20.0106             0.747967                 0.961066
# 4           9.6253             0.471545                 0.848361
# ..             ...                  ...                      ...
# 500        9.76018             0.628049                 0.047131
# 501        8.29982             0.024390                 0.412910
# 502        11.8758             0.829268                 0.829918
# 503        3.06022             0.418699                 0.114754
# 504        17.7969             0.821138                 0.922131
#
#      priceToSales Percentiles  EV/EBITDA Percentiles  \
# 0                    0.800205               0.877049
# 1                    0.032787               0.030738
# 2                    0.154713               0.260246
# 3                    0.831967               0.819672
# 4                    0.674180               0.510246
# ..                        ...                    ...
# 500                  0.731557               0.698770
# 501                  0.680328               0.827869
# 502                  0.700820               0.864754
# 503                  0.437500               0.282787
# 504                  0.920082               0.872951
#
#      EV/GrossProfit Percentiles
# 0                      0.797131
# 1                      0.057377
# 2                      0.114754
# 3                      0.930328
# 4                      0.639344
# ..                          ...
# 500                    0.649590
# 501                    0.561475
# 502                    0.729508
# 503                    0.157787
# 504                    0.899590
#
# [505 rows x 12 columns]

# %%
# robust value(RV) score = mean of those percentiles
multiples_ratio_portfolio['RV score'] = multiples_ratio_portfolio.filter(like='Percentiles').mean(axis=1)

# %%
multiples_ratio_portfolio
# Out:
#     Ticker latestPrice peRatio priceToBook priceToSales EV/EBITDA  \
# 0        A      127.02   54.53        8.06         7.21   33.9211
# 1      AAL        17.8   -1.27          -2        0.448  -6.39962
# 2      AAP      162.69   24.05        2.89         1.13   11.0634
# 3     AAPL     137.749   38.06        35.6          8.2    27.578
# 4     ABBV      108.64    24.5       12.85         4.85   16.4082
# ..     ...         ...     ...         ...          ...       ...
# 500    YUM      103.08   31.04       -4.09         5.69   22.0002
# 501    ZBH      163.62 -219.34         2.9         4.92   28.5296
# 502   ZBRA      410.07   48.01       11.53         5.15   31.5201
# 503   ZION       48.77   21.43        1.12         2.71   11.5968
# 504    ZTS      159.51   47.18       20.81        11.45    32.839
#
#     EV/GrossProfit  peRatio Percentiles  priceToBook Percentiles  \
# 0          13.7335             0.861789                 0.772541
# 1          1.46476             0.157520                 0.051230
# 2          2.48007             0.469512                 0.409836
# 3          20.0106             0.747967                 0.961066
# 4           9.6253             0.471545                 0.848361
# ..             ...                  ...                      ...
# 500        9.76018             0.628049                 0.047131
# 501        8.29982             0.024390                 0.412910
# 502        11.8758             0.829268                 0.829918
# 503        3.06022             0.418699                 0.114754
# 504        17.7969             0.821138                 0.922131
#
#      priceToSales Percentiles  EV/EBITDA Percentiles  \
# 0                    0.800205               0.877049
# 1                    0.032787               0.030738
# 2                    0.154713               0.260246
# 3                    0.831967               0.819672
# 4                    0.674180               0.510246
# ..                        ...                    ...
# 500                  0.731557               0.698770
# 501                  0.680328               0.827869
# 502                  0.700820               0.864754
# 503                  0.437500               0.282787
# 504                  0.920082               0.872951
#
#      EV/GrossProfit Percentiles  RV score
# 0                      0.797131  0.821743
# 1                      0.057377  0.065930
# 2                      0.114754  0.281812
# 3                      0.930328  0.858200
# 4                      0.639344  0.628735
# ..                          ...       ...
# 500                    0.649590  0.551020
# 501                    0.561475  0.501394
# 502                    0.729508  0.790854
# 503                    0.157787  0.282305
# 504                    0.899590  0.887178
#
# [505 rows x 13 columns]

# %%
multiples_ratio_portfolio.sort_values(by='RV score', inplace=True)
multiples_ratio_portfolio.reset_index(drop=True, inplace=True)
multiples_ratio_portfolio = multiples_ratio_portfolio[:50]
multiples_ratio_portfolio.head(10)
# Out:
#   Ticker latestPrice peRatio priceToBook priceToSales EV/EBITDA  \
# 0    UNM       25.12     5.5      0.4696       0.4356   2.67642
# 1    AIG       41.42   -7.31      0.5622       0.7787   4.70545
# 2    AAL        17.8   -1.27          -2        0.448  -6.39962
# 3    MCK      194.82   -7.58      -64.87       0.1253   7.45415
# 4      F       11.43    -284        1.35       0.3406   4.66145
# 5    MET        54.1    8.66      0.6538       0.7239   4.81161
# 6    ALL      109.96     7.8        1.33       0.7494   2.41517
# 7    HIG       52.97   10.69        1.09       0.8873   4.28064
# 8    FTI       11.51    -0.9        1.27       0.3937   3.52439
# 9     BA      216.15  -10.52        -6.7         2.13  -14.7246
#
#   EV/GrossProfit  peRatio Percentiles  priceToBook Percentiles  \
# 0        0.40798             0.174797                 0.057377
# 1       0.777124             0.115854                 0.061475
# 2        1.46476             0.157520                 0.051230
# 3        2.78491             0.113821                 0.010246
# 4        2.32671             0.022358                 0.168033
# 5       0.715566             0.186992                 0.065574
# 6        0.72266             0.178862                 0.159836
# 7       0.851303             0.209350                 0.109631
# 8        2.27375             0.160569                 0.142418
# 9       -29.1124             0.103659                 0.043033
#
#    priceToSales Percentiles  EV/EBITDA Percentiles  \
# 0                  0.030738               0.036885
# 1                  0.077869               0.045082
# 2                  0.032787               0.030738
# 3                  0.004098               0.090164
# 4                  0.012295               0.043033
# 5                  0.065574               0.047131
# 6                  0.071721               0.034836
# 7                  0.092213               0.040984
# 8                  0.026639               0.038934
# 9                  0.348361               0.022541
#
#    EV/GrossProfit Percentiles  RV score
# 0                    0.004098  0.060779
# 1                    0.018443  0.063745
# 2                    0.057377  0.065930
# 3                    0.137295  0.071125
# 4                    0.110656  0.071275
# 5                    0.012295  0.075513
# 6                    0.014344  0.091920
# 7                    0.024590  0.095354
# 8                    0.108607  0.095433
# 9                    0.002049  0.103928

# %%
multiples_ratio_portfolio.shape
# Out:
# (50, 13)

# %%
get_equal_position_size(multiples_ratio_portfolio.shape[0])
# Out:
# Enter the size of portfolio: fsd,l
# Invalid Input!
# Enter the size of portfolio: 5821498
# Porfolio size: 5821498.0
# Position size: 116429.96

# %%
multiples_ratio_portfolio['Amount of shares to buy'] = np.floor(position_size/multiples_ratio_portfolio.latestPrice)
# Out:
# <ipython-input-46-925aa2456434>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiples_ratio_portfolio['Amount of shares to buy'] = np.floor(position_size/multiples_ratio_portfolio.latestPrice)

# %%
multiples_ratio_portfolio.head(10)
# Out:
#   Ticker latestPrice peRatio priceToBook priceToSales EV/EBITDA  \
# 0    UNM       25.12     5.5      0.4696       0.4356   2.67642
# 1    AIG       41.42   -7.31      0.5622       0.7787   4.70545
# 2    AAL        17.8   -1.27          -2        0.448  -6.39962
# 3    MCK      194.82   -7.58      -64.87       0.1253   7.45415
# 4      F       11.43    -284        1.35       0.3406   4.66145
# 5    MET        54.1    8.66      0.6538       0.7239   4.81161
# 6    ALL      109.96     7.8        1.33       0.7494   2.41517
# 7    HIG       52.97   10.69        1.09       0.8873   4.28064
# 8    FTI       11.51    -0.9        1.27       0.3937   3.52439
# 9     BA      216.15  -10.52        -6.7         2.13  -14.7246
#
#   EV/GrossProfit  peRatio Percentiles  priceToBook Percentiles  \
# 0        0.40798             0.174797                 0.057377
# 1       0.777124             0.115854                 0.061475
# 2        1.46476             0.157520                 0.051230
# 3        2.78491             0.113821                 0.010246
# 4        2.32671             0.022358                 0.168033
# 5       0.715566             0.186992                 0.065574
# 6        0.72266             0.178862                 0.159836
# 7       0.851303             0.209350                 0.109631
# 8        2.27375             0.160569                 0.142418
# 9       -29.1124             0.103659                 0.043033
#
#    priceToSales Percentiles  EV/EBITDA Percentiles  \
# 0                  0.030738               0.036885
# 1                  0.077869               0.045082
# 2                  0.032787               0.030738
# 3                  0.004098               0.090164
# 4                  0.012295               0.043033
# 5                  0.065574               0.047131
# 6                  0.071721               0.034836
# 7                  0.092213               0.040984
# 8                  0.026639               0.038934
# 9                  0.348361               0.022541
#
#    EV/GrossProfit Percentiles  RV score Amount of shares to buy
# 0                    0.004098  0.060779                    4634
# 1                    0.018443  0.063745                    2810
# 2                    0.057377  0.065930                    6541
# 3                    0.137295  0.071125                     597
# 4                    0.110656  0.071275                   10186
# 5                    0.012295  0.075513                    2152
# 6                    0.014344  0.091920                    1058
# 7                    0.024590  0.095354                    2198
# 8                    0.108607  0.095433                   10115
# 9                    0.002049  0.103928                     538

# %% [markdown]
# # save to excel

# %%
writer = pd.ExcelWriter(path='value_strategy_portfolio.xlsx', engine='xlsxwriter')

# %%
quant_value_portfolio.to_excel(writer, sheet_name='basic PE based', index=False)
multiples_ratio_portfolio.to_excel(writer, sheet_name='multiple ratios based', index=False)

# %%
writer.save()
