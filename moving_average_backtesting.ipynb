# %%
from backtester import *

# %%
data = pd.read_csv('FXCM/historical_prices/H1/EUR_USD_H1.csv', parse_dates=['date'], index_col=['date'])

# %%
ma_backtest = MovingAverageBacktester(data=data, freq='H1', periods=(20,120), kind='SMA')
ma_backtest.backtest()
# Out:
# 100%|██████████| 9880/9880 [00:01<00:00, 5187.42it/s]

# %%
ma_backtest.plot_portfolio()

# %%
ma_backtest.show_returns()
ma_backtest.show_stdevs()
ma_backtest.print_sharpe_ratio()
ma_backtest.show_drawdown()
# Out:
# ...
# Portfolio Returns
# Data Length: 572 days 16:00:00
# ...
# ***** Benchmark *****
# Total Return: 9.58 %
# Annualized Return: 5.71 %
# Monthly Return: 0.47 %
# ----------------------------------------
# ***** Portfolio *****
# Total Return: 18.17 %
# Annualized Return: 10.67 %
# Monthly Return: 0.86 %
# ----------------------------------------
# ***** Alpha *****
# Total Return: 8.59 %
# Annualized Return: 4.96 %
# Monthly Return: 0.39 %
# ----------------------------------------
# ...
# Portfolio(rebased to 1) Standard Deviation
# Data Length: 572 days 16:00:00
# ...
# ***** Benchmark *****
# Total Stdev: 4.36 %
# Annualized Stdev: 3.40 %
# Monthly Stdev: 0.98 %
# ----------------------------------------
# ***** Portfolio *****
# Total Stdev: 6.10 %
# Annualized Stdev: 4.76 %
# Monthly Stdev: 1.38 %
# ----------------------------------------
# ...
# Annual Sharpe Ratio
# Data Length: 572 days 16:00:00
# ...
# Benchmark: 1.68
# Portfolio: 2.24
# ----------------------------------------
# ...
# Maximum Drawdown
# ...
